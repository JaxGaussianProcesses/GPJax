# %%
# %load_ext lab_black

# %%
import torch
from torch import nn
from torch import Tensor
import matplotlib.pyplot as plt
from multipledispatch import dispatch
import torch.distributions as td

# %%
class Kernel(nn.Module):
    pass


class Stationary(Kernel):
    @staticmethod
    def _pairwise(x, y):
        # L2 norm
        return torch.cdist(x, y, p=2)


class RBF(Stationary):
    def __init__(
        self, lengthscale: Tensor = torch.ones(1), variance: Tensor = torch.ones(1)
    ):
        super().__init__()
        self.lengthscale = nn.Parameter(lengthscale)
        self.variance = nn.Parameter(variance)

    def forward(self, x, y, jitter: float = 1e-5):
        D2 = torch.square(self._pairwise(x, y))
        gram = torch.square(self.variance) * torch.exp(
            -D2 / (2 * torch.square(self.lengthscale))
        )
        if x.shape[0] == y.shape[0]:
            gram += torch.eye(x.shape[0]) * jitter
        return gram

# %%
class MeanFunction(nn.Module):
    pass


class Zero(MeanFunction):
    def forward(self, x):
        return torch.zeros_like(x)

# %%
class Prior(nn.Module):
    def __init__(self, kernel: Kernel, mean_function: MeanFunction):
        pass

# %%
x = torch.linspace(-3.0, 3.0, 100).reshape(-1, 1)
m = Zero()
mu = m(x)

# %%
kernel = RBF()
K = kernel.forward(x, x)

# %%
def _is_pos_def(A):
    return torch.all(torch.eig(A, eigenvectors=False)[0][:, 0] > 0)

# %%
_is_pos_def(K)
# Out:
# tensor(True)

# %%
class Likelihood(nn.Module):
    pass


class Gaussian(Likelihood):
    def __init__(self, noise: float = torch.ones(1)):
        super().__init__()
        self.noise = nn.Parameter(noise)

# %%
class GP(nn.Module):
    pass


class Prior(GP):
    def __init__(self, kernel: Kernel, mean_function: MeanFunction = Zero()):
        super().__init__()
        self.meanf = mean_function
        self.kernel = kernel

    def __mul__(self, other: Likelihood):
        return Posterior(self, other)


class Posterior(GP):
    def __init__(self, prior: Prior, likelihood: Likelihood):
        super().__init__()
        self.prior = prior
        self.likelihood = likelihood
        self.meanf = prior.meanf
        self.kernel = prior.kernel

# %%
prior = Prior(kernel)
lik = Gaussian()
posterior = prior * lik

# %%
@dispatch(Prior, Tensor)
def sample(gp: Prior, x: Tensor):
    mu = gp.meanf(x)
    Sigma = gp.kernel(x, x)
    random_v = td.MultivariateNormal(mu.squeeze(), Sigma)
    return random_v


@dispatch(Posterior, Tensor, Tensor, Tensor)
def sample(gp: Posterior, x_train: Tensor, y_train: Tensor, x_test: Tensor):
    Kxx = gp.kernel(x_train, x_train, jitter=0) + torch.eye(
        x_train.shape[0]
    ) * torch.square(gp.likelihood.noise)
    Kxstar = gp.kernel(x_train, x_test)
    Kstar = gp.kernel(x_test, x_test)
    Kinv = torch.inverse(Kxx)

    mu = torch.matmul(torch.matmul(Kxstar.T, Kinv), y_train)
    Sigma = Kstar - torch.matmul(torch.matmul(Kxstar.T, Kinv), Kxstar)

    rv = td.MultivariateNormal(mu.squeeze(), Sigma)
    return rv

# %%
xtr = torch.linspace(-3.0, 3.0, 100).reshape(-1, 1)
ytr = torch.sin(x)
xte = torch.linspace(-4.0, 4.0, 500).reshape(-1, 1)

prior_rv = sample(prior, xtr)
posterior_rv = sample(posterior, xtr, ytr, xte)

prior_samples = prior_rv.sample(sample_shape=(20,))
posterior_samples = posterior_rv.sample(sample_shape=(20,))

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12, 4))
ax[0].plot(xtr, prior_samples.T, color="orange", alpha=0.5)
ax[0].set_title("Prior samples")
ax[1].plot(xtr, ytr, "o")
ax[1].plot(xte, posterior_samples.T, color="orange", alpha=0.5)
ax[1].set_title("Posterior samples")
plt.show()

# %%
def marginal_ll(gp: Posterior, X: Tensor, y: Tensor):
    N = X.shape[0]
    pi = torch.tensor(3.14159265359)
    Kxx = gp.kernel(X, X, jitter=0) + torch.eye(N) * torch.square(gp.likelihood.noise)
    L = torch.cholesky(Kxx)
    diag_sum = torch.sum(torch.log(torch.diag(L)))
    alpha = torch.lstsq(torch.lstsq(y, L)[0], L.T)[0]
    temp = torch.matmul(y.T, alpha)
    objective = (
        diag_sum + (0.5 * torch.matmul(y.T, alpha)) + 0.5 * N * torch.log(2 * pi)
    )
    return objective


marginal_ll(posterior, xtr, ytr)
# Out:
# tensor([[100.7163]], grad_fn=<AddBackward0>)

# %%
# Out:
# tensor([[99.7007, 99.7002, 99.7047,  ..., 99.7475, 99.7330, 99.7192],
#         [99.7014, 99.5966, 99.6543,  ..., 99.6599, 99.6678, 99.6753],
#         [99.7033, 99.7344, 99.5860,  ..., 99.6697, 99.6751, 99.6802],
#         ...,
#         [99.7006, 99.6978, 99.6998,  ..., 99.8033, 99.6910, 99.6912],
#         [99.7016, 99.6985, 99.7008,  ..., 99.6584, 99.7778, 99.6910],
#         [99.7026, 99.6992, 99.7017,  ..., 99.6631, 99.6658, 99.7520]],
#        grad_fn=<AddBackward0>)
