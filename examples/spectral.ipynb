# %%
# %load_ext lab_black

# %%
import sys

sys.path.append("..")
from gpjax import Prior, SpectralRBF, Gaussian, ZeroMean
import jax
import jax.numpy as jnp
import jax.random as jr
import objax
import numpy as onp
import matplotlib.pyplot as plt

key = jr.PRNGKey(123)
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
N = 1000
noise = 0.1

X = jr.uniform(key=key, minval=-3.0, maxval=3.0, shape=(N,)).sort().reshape(-1, 1)
# X = X.sort()
f = lambda x: jnp.sin(4 * x) + jnp.cos(2 * x)
signal = f(X)
y = signal + jr.normal(key, shape=signal.shape) * noise
Xtest = jnp.linspace(-3.5, 3.5, 500).reshape(-1, 1)
ytest = f(Xtest)

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(Xtest, ytest, label="Latent function")
ax.plot(X, y, "o", label="Observations", alpha=0.5)
ax.legend(loc="best")
# plt.savefig("data.png")

# %%
kernel = SpectralRBF(
    num_basis=50, lengthscale=jnp.array([1.0]), variance=jnp.array([1.0])
)
meanf = ZeroMean()

prior = Prior(kernel=kernel, mean_function=meanf, jitter=1e-6)

# %%
samples = prior.sample(X, key, n_samples=20)
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(X, samples.T, color="orange", alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# FilteredStackTrace                        Traceback (most recent call last)
# <ipython-input-6-7610a3dfdd0c> in <module>
# ----> 1 samples = prior.sample(X, key, n_samples=20)
#       2 fig, ax = plt.subplots(figsize=(10, 5))
#       3 ax.plot(X, samples.T, color="orange", alpha=0.5)
#
# ~/Documents/GPBlocks/gpjax/gp.py in sample(self, X, key, n_samples)
#      28             cov += Inn
# ---> 29         return jr.multivariate_normal(key,
#      30                                       mu.squeeze(),
#
# ~/.local/lib/python3.8/site-packages/jax/random.py in multivariate_normal(key, mean, cov, shape, dtype)
#     680     shape = abstract_arrays.canonicalize_shape(shape)
# --> 681   return _multivariate_normal(key, mean, cov, shape, dtype)  # type: ignore
#     682
#
# ~/.local/lib/python3.8/site-packages/jax/random.py in _multivariate_normal(key, mean, cov, shape, dtype)
#     694            "but got cov.shape == {shape}.")
# --> 695     raise ValueError(msg.format(n=n, shape=np.shape(cov)))
#     696
#
# FilteredStackTrace: ValueError: multivariate_normal requires cov.shape == (..., n, n) for n=1000, but got cov.shape == (2000, 2000).
#
# The stack trace above excludes JAX-internal frames.
# The following is the original exception that occurred, unmodified.
#
# --------------------
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-7610a3dfdd0c> in <module>
# ----> 1 samples = prior.sample(X, key, n_samples=20)
#       2 fig, ax = plt.subplots(figsize=(10, 5))
#       3 ax.plot(X, samples.T, color="orange", alpha=0.5)
#
# ~/Documents/GPBlocks/gpjax/gp.py in sample(self, X, key, n_samples)
#      27             Inn = jnp.eye(cov.shape[0])*self.jitter
#      28             cov += Inn
# ---> 29         return jr.multivariate_normal(key,
#      30                                       mu.squeeze(),
#      31                                       cov,
#
# ~/.local/lib/python3.8/site-packages/jax/random.py in multivariate_normal(key, mean, cov, shape, dtype)
#     679   if shape is not None:
#     680     shape = abstract_arrays.canonicalize_shape(shape)
# --> 681   return _multivariate_normal(key, mean, cov, shape, dtype)  # type: ignore
#     682
#     683 @partial(jit, static_argnums=(3, 4))
#
# ~/.local/lib/python3.8/site-packages/jax/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     131   def reraise_with_filtered_traceback(*args, **kwargs):
#     132     try:
# --> 133       return fun(*args, **kwargs)
#     134     except Exception as e:
#     135       if not is_under_reraiser(e):
#
# ~/.local/lib/python3.8/site-packages/jax/api.py in f_jitted(*args, **kwargs)
#     215       _check_arg(arg)
#     216     flat_fun, out_tree = flatten_fun(f, in_tree)
# --> 217     out = xla.xla_call(
#     218         flat_fun,
#     219         *args_flat,
#
# ~/.local/lib/python3.8/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1175
#    1176   def bind(self, fun, *args, **params):
# -> 1177     return call_bind(self, fun, *args, **params)
#    1178
#    1179   def process(self, trace, fun, tracers, params):
#
# ~/.local/lib/python3.8/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1166   tracers = map(top_trace.full_raise, args)
#    1167   with maybe_new_sublevel(top_trace):
# -> 1168     outs = primitive.process(top_trace, fun, tracers, params)
#    1169   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1170
#
# ~/.local/lib/python3.8/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1178
#    1179   def process(self, trace, fun, tracers, params):
# -> 1180     return trace.process_call(self, fun, tracers, params)
#    1181
#    1182   def post_process(self, trace, out_tracers, params):
#
# ~/.local/lib/python3.8/site-packages/jax/core.py in process_call(self, primitive, f, tracers, params)
#     577
#     578   def process_call(self, primitive, f, tracers, params):
# --> 579     return primitive.impl(f, *tracers, **params)
#     580   process_map = process_call
#     581
#
# ~/.local/lib/python3.8/site-packages/jax/interpreters/xla.py in _xla_call_impl(fun, device, backend, name, donated_invars, *args)
#     554
#     555 def _xla_call_impl(fun: lu.WrappedFun, *args, device, backend, name, donated_invars):
# --> 556   compiled_fun = _xla_callable(fun, device, backend, name, donated_invars,
#     557                                *unsafe_map(arg_spec, args))
#     558   try:
#
# ~/.local/lib/python3.8/site-packages/jax/linear_util.py in memoized_fun(fun, *args)
#     249       fun.populate_stores(stores)
#     250     else:
# --> 251       ans = call(fun, *args)
#     252       cache[key] = (ans, fun.stores)
#     253
#
# ~/.local/lib/python3.8/site-packages/jax/interpreters/xla.py in _xla_callable(fun, device, backend, name, donated_invars, *arg_specs)
#     630   abstract_args, arg_devices = unzip2(arg_specs)
#     631   if config.omnistaging_enabled:
# --> 632     jaxpr, out_avals, consts = pe.trace_to_jaxpr_final(fun, abstract_args)
#     633     if any(isinstance(c, core.Tracer) for c in consts):
#     634       raise core.UnexpectedTracerError("Encountered an unexpected tracer.")
#
# ~/.local/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in trace_to_jaxpr_final(fun, in_avals)
#    1191     main.source_info = fun_sourceinfo(fun.f)  # type: ignore
#    1192     main.jaxpr_stack = ()  # type: ignore
# -> 1193     jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1194     del main
#    1195   return jaxpr, out_avals, consts
#
# ~/.local/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1172     trace = DynamicJaxprTrace(main, core.cur_sublevel())
#    1173     in_tracers = map(trace.new_arg, in_avals)
# -> 1174     ans = fun.call_wrapped(*in_tracers)
#    1175     out_tracers = map(trace.full_raise, ans)
#    1176   jaxpr, out_avals, consts = frame.to_jaxpr(in_tracers, out_tracers)
#
# ~/.local/lib/python3.8/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     158
#     159     try:
# --> 160       ans = self.f(*args, **dict(self.params, **kwargs))
#     161     except:
#     162       # Some transformations yield from inside context managers, so we have to
#
# ~/.local/lib/python3.8/site-packages/jax/random.py in _multivariate_normal(key, mean, cov, shape, dtype)
#     693     msg = ("multivariate_normal requires cov.shape == (..., n, n) for n={n}, "
#     694            "but got cov.shape == {shape}.")
# --> 695     raise ValueError(msg.format(n=n, shape=np.shape(cov)))
#     696
#     697   if shape is None:
#
# ValueError: multivariate_normal requires cov.shape == (..., n, n) for n=1000, but got cov.shape == (2000, 2000).
